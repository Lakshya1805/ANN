# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/graduate-admissions/Admission_Predict.csv
# /kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv

# %%
df = pd.read_csv('/kaggle/input/graduate-admissions/Admission_Predict.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.drop(columns='Serial No.',inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
from sklearn.model_selection import train_test_split

# %%
x= df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

x_train_trf = scaler.fit_transform(x_train)
x_test_trf = scaler.fit_transform(x_test)

# %%
import tensorflow
from tensorflow import keras
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(5,activation='relu'))
model.add(Dense(3,activation='relu'))
model.add(Dense(1,activation = 'linear'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 7)                 56
#
#  dense_8 (Dense)             (None, 5)                 40
#
#  dense_9 (Dense)             (None, 3)                 18
#
#  dense_10 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 118
# Trainable params: 118
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error',optimizer='Adam')

# %%
model.fit(x_train,y_train,epochs=100,validation_split=0.1)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 20ms/step - loss: 0.5466 - val_loss: 0.5236
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5335 - val_loss: 0.5109
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5208 - val_loss: 0.4984
# Epoch 4/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5082 - val_loss: 0.4861
# Epoch 5/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4960 - val_loss: 0.4740
# Epoch 6/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4839 - val_loss: 0.4622
# Epoch 7/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4719 - val_loss: 0.4506
# Epoch 8/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4603 - val_loss: 0.4393
# Epoch 9/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4489 - val_loss: 0.4281
# Epoch 10/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4377 - val_loss: 0.4172
# Epoch 11/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4267 - val_loss: 0.4066
# Epoch 12/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4160 - val_loss: 0.3960
# Epoch 13/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4054 - val_loss: 0.3858
# Epoch 14/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3952 - val_loss: 0.3757
# Epoch 15/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3850 - val_loss: 0.3658
# Epoch 16/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3751 - val_loss: 0.3562
# Epoch 17/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3654 - val_loss: 0.3468
# Epoch 18/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3559 - val_loss: 0.3376
# Epoch 19/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3466 - val_loss: 0.3285
# Epoch 20/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3376 - val_loss: 0.3197
# Epoch 21/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3287 - val_loss: 0.3110
# Epoch 22/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3199 - val_loss: 0.3025
# Epoch 23/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3114 - val_loss: 0.2943
# Epoch 24/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3031 - val_loss: 0.2862
# Epoch 25/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2949 - val_loss: 0.2783
# Epoch 26/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2870 - val_loss: 0.2705
# Epoch 27/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2792 - val_loss: 0.2630
# Epoch 28/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2716 - val_loss: 0.2556
# Epoch 29/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2642 - val_loss: 0.2483
# Epoch 30/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2569 - val_loss: 0.2413
# Epoch 31/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2497 - val_loss: 0.2345
# Epoch 32/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2429 - val_loss: 0.2277
# Epoch 33/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2361 - val_loss: 0.2212
# Epoch 34/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2295 - val_loss: 0.2148
# Epoch 35/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2231 - val_loss: 0.2085
# Epoch 36/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2167 - val_loss: 0.2025
# Epoch 37/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2107 - val_loss: 0.1965
# Epoch 38/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2046 - val_loss: 0.1908
# Epoch 39/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1988 - val_loss: 0.1851
# Epoch 40/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1931 - val_loss: 0.1796
# Epoch 41/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1875 - val_loss: 0.1743
# Epoch 42/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1821 - val_loss: 0.1691
# Epoch 43/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1769 - val_loss: 0.1640
# Epoch 44/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1718 - val_loss: 0.1590
# Epoch 45/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1667 - val_loss: 0.1542
# Epoch 46/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1619 - val_loss: 0.1495
# Epoch 47/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1571 - val_loss: 0.1450
# Epoch 48/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1526 - val_loss: 0.1405
# Epoch 49/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1480 - val_loss: 0.1362
# Epoch 50/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1437 - val_loss: 0.1320
# Epoch 51/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1394 - val_loss: 0.1280
# Epoch 52/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1353 - val_loss: 0.1240
# Epoch 53/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1313 - val_loss: 0.1201
# Epoch 54/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1274 - val_loss: 0.1164
# Epoch 55/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1235 - val_loss: 0.1128
# Epoch 56/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1199 - val_loss: 0.1093
# Epoch 57/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1164 - val_loss: 0.1058
# Epoch 58/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1129 - val_loss: 0.1025
# Epoch 59/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1095 - val_loss: 0.0993
# Epoch 60/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1062 - val_loss: 0.0962
# Epoch 61/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1030 - val_loss: 0.0932
# Epoch 62/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1000 - val_loss: 0.0902
# Epoch 63/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0970 - val_loss: 0.0874
# Epoch 64/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0941 - val_loss: 0.0846
# Epoch 65/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0913 - val_loss: 0.0819
# Epoch 66/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0886 - val_loss: 0.0794
# Epoch 67/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0859 - val_loss: 0.0769
# Epoch 68/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0834 - val_loss: 0.0745
# Epoch 69/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0809 - val_loss: 0.0721
# Epoch 70/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0786 - val_loss: 0.0699
# Epoch 71/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0762 - val_loss: 0.0677
# Epoch 72/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0740 - val_loss: 0.0656
# Epoch 73/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0635
# Epoch 74/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0698 - val_loss: 0.0616
# Epoch 75/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0677 - val_loss: 0.0597
# Epoch 76/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0658 - val_loss: 0.0578
# Epoch 77/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0639 - val_loss: 0.0561
# Epoch 78/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0621 - val_loss: 0.0544
# Epoch 79/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0603 - val_loss: 0.0527
# Epoch 80/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0586 - val_loss: 0.0511
# Epoch 81/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0570 - val_loss: 0.0496
# Epoch 82/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0554 - val_loss: 0.0481
# Epoch 83/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0539 - val_loss: 0.0467
# Epoch 84/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0524 - val_loss: 0.0453
# Epoch 85/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0510 - val_loss: 0.0440
# Epoch 86/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0497 - val_loss: 0.0427
# Epoch 87/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0483 - val_loss: 0.0416
# Epoch 88/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0471 - val_loss: 0.0404
# Epoch 89/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0459 - val_loss: 0.0393
# Epoch 90/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0447 - val_loss: 0.0382
# Epoch 91/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0436 - val_loss: 0.0371
# Epoch 92/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0425 - val_loss: 0.0361
# Epoch 93/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0415 - val_loss: 0.0352
# Epoch 94/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0405 - val_loss: 0.0343
# Epoch 95/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0396 - val_loss: 0.0334
# Epoch 96/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0386 - val_loss: 0.0326
# Epoch 97/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0378 - val_loss: 0.0318
# Epoch 98/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0369 - val_loss: 0.0310
# Epoch 99/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0361 - val_loss: 0.0303
# Epoch 100/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0353 - val_loss: 0.0296

# %%
y_pred = model.predict(x_test)
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# -0.4417485751437722
